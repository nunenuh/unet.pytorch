# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import random
import pathlib
import torch.utils.data as data
import PIL
import PIL.Image
from torchvision.datasets import ImageFolder
import pandas as pd

import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
from unet.prod import SegmentationPredictor
unet_path = 'weights/unet_sfeat32_v2.pth'
segment = SegmentationPredictor(weight_path=unet_path)

# %%
# im_path = '/data/idcard/combined/1609935833/182_image.jpg'
im_path = '/data/idcard/fandi_ktp/ktp2.jpg'
# im_path = '/data/idcard/ktp_aan/ktp6.jpg'
image,mask,combined = segment.predict(im_path)

# %%
import numpy as np
np.array(combined.convert("RGB")).shape
# Out:
# (960, 1280, 3)

# %%
image.resize(size=(1000//2,750//2))
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F91FD5CAE48>

# %%
mask.resize(size=(1000//2,750//2))
# Out:
# <PIL.Image.Image image mode=L size=500x375 at 0x7F91F8519D68>

# %%
combined.resize(size=(1000//2,750//2))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x375 at 0x7F91F8519D30>
